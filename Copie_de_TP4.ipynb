# %% [markdown]
# <a href="https://colab.research.google.com/github/mdata-marcel/DATA-IA/blob/main/Copie_de_TP4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# **Astuce pour afficher tout les détails de toutes les informations des types de varaibles du DATASET**

# %%
pd.set_option('display.max_row', 111)
pd.set_option('display.max_columns', 111)

# %%
# Charger le jeu de données

# %%
covid = pd.read_csv('dataset_covid.csv', encoding='ISO-8859-1')

# %%
# Afficher les 6 premieres Lignes

# %%
covid.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %% [markdown]
# **Check List de BASE**

# %% [markdown]
# **Variable target : ** SARS-Cov-2 exam result

# %% [markdown]
# Ligne et *colonnes*

# %%
covid.shape
# Out:
# (5644, 111)

# %% [markdown]
# **Types de variables **

# %%
covid.dtypes
# Out:
# Patient ID                                                object
# Patient age quantile                                       int64
# SARS-Cov-2 exam result                                    object
# Patient addmited to regular ward (1=yes, 0=no)             int64
# Patient addmited to semi-intensive unit (1=yes, 0=no)      int64
# Patient addmited to intensive care unit (1=yes, 0=no)      int64
# Hematocrit                                               float64
# Hemoglobin                                               float64
# Platelets                                                float64
# Mean platelet volume                                     float64
# Red blood Cells                                          float64
# Lymphocytes                                              float64
# Mean corpuscular hemoglobin concentration (MCHC)         float64
# Leukocytes                                               float64
# ...

# %%
covid.dtypes.value_counts()
# Out:
# float64    70
# object     37
# int64       4
# dtype: int64

# %%
covid.dtypes.value_counts().plot.pie()
# Out:
# <Axes: >

# %% [markdown]
# **ANALYSONS LES VALEURS MANQUANTES**

# %% [markdown]
# **Vérifier si une valeur est vraie ou fausse avec Pandas.**

# %%
covid.isna()
# Out:
#       Patient ID  Patient age quantile  SARS-Cov-2 exam result  \
# 0          False                 False                   False
# 1          False                 False                   False
# 2          False                 False                   False
# 3          False                 False                   False
# 4          False                 False                   False
# ...          ...                   ...                     ...
# 5639       False                 False                   False
# 5640       False                 False                   False
# 5641       False                 False                   False
# 5642       False                 False                   False
# 5643       False                 False                   False
#
#       Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                              False
# 1                                              False
# ...

# %% [markdown]
# **Vérifier si une valeur est vraie ou fausse avec seaborn.**

# %%
plt.figure(figsize=(10,5)) #Permet d'agrandir la figure
sns.heatmap(covid.isna(), cbar=False)
# Out:
# <Axes: >

# %%
#Mesurer le pourcentage de valeur manquante
(covid.isna().sum()/covid.shape[0]).sort_values(ascending=True)
# Out:
# Patient ID                                               0.000000
# Patient age quantile                                     0.000000
# SARS-Cov-2 exam result                                   0.000000
# Patient addmited to regular ward (1=yes, 0=no)           0.000000
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.000000
# Patient addmited to intensive care unit (1=yes, 0=no)    0.000000
# Influenza B                                              0.760099
# Respiratory Syncytial Virus                              0.760099
# Influenza A                                              0.760099
# Rhinovirus/Enterovirus                                   0.760454
# Inf A H1N1 2009                                          0.760454
# CoronavirusOC43                                          0.760454
# Coronavirus229E                                          0.760454
# Parainfluenza 4                                          0.760454
# ...

# %% [markdown]
# **ANALYSE DE FOND**

# %% [markdown]
# **1 - Visualisation initiale - Eliminations des colonnes inutiles **

# %%
covid = covid[covid.columns[covid.isna().sum()/covid.shape[0] < 0.9]]

# %%
covid.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
# Affichons les valeurs manquantes à nouveau
plt.figure(figsize=(10,5)) #Permet d'agrandir la figure
sns.heatmap(covid.isna(), cbar=False)
# Out:
# <Axes: >

# %%
# Eliminons la colonne Patient ID qui ne sert à rien
covid = covid.drop('Patient ID', axis=1)

# %%
covid.head()
# Out:
#    Patient age quantile SARS-Cov-2 exam result  \
# 0                    13               negative
# 1                    17               negative
# 2                     8               negative
# 3                     5               negative
# 4                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# ...

# %% [markdown]
# **Visualisation de la Variable target **

# %% [markdown]
# Examen de la colonne Target

# %%
# Vérifcation du taux
covid['SARS-Cov-2 exam result'].value_counts(normalize=True)
# Out:
# negative    0.901134
# positive    0.098866
# Name: SARS-Cov-2 exam result, dtype: float64

# %% [markdown]
# **Significations de la variable **

# %%
# Histogrammes des variables continues

# %%
for col in covid.select_dtypes('float'):
  print(col)
# Out:
# Hematocrit
# Hemoglobin
# Platelets
# Mean platelet volume
# Red blood Cells
# Lymphocytes
# Mean corpuscular hemoglobin concentration (MCHC)
# Leukocytes
# Basophils
# Mean corpuscular hemoglobin (MCH)
# Eosinophils
# Mean corpuscular volume (MCV)
# Monocytes
# Red blood cell distribution width (RDW)

# %%
# Visualisation avec Seaborn
for col in covid.select_dtypes('float'):
  plt.figure()
  sns.distplot(covid[col])
# Out:
# <ipython-input-313-914c9cb043be>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(covid[col])
# <ipython-input-313-914c9cb043be>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(covid[col])
# <ipython-input-313-914c9cb043be>:4: UserWarning:
#
# ...

# %%
# Visualisation de la variable Patient age quantile
sns.distplot(covid['Patient age quantile'])
# Out:
# <ipython-input-314-c0c3d272945b>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(covid['Patient age quantile'])
# <Axes: xlabel='Patient age quantile', ylabel='Density'>

# %% [markdown]
# **VARIABLES QUALITATIVES**

# %%
# Vérifier les catégories de chaque variable
covid['SARS-Cov-2 exam result'].unique()
# Out:
# array(['negative', 'positive'], dtype=object)

# %%
#
for col in covid.select_dtypes('object'):
  print(f'{col :-<50}, {covid[col].unique()}') # Améliorer l'affichage
# Out:
# SARS-Cov-2 exam result----------------------------, ['negative' 'positive']
# Respiratory Syncytial Virus-----------------------, [nan 'not_detected' 'detected']
# Influenza A---------------------------------------, [nan 'not_detected' 'detected']
# Influenza B---------------------------------------, [nan 'not_detected' 'detected']
# Parainfluenza 1-----------------------------------, [nan 'not_detected' 'detected']
# CoronavirusNL63-----------------------------------, [nan 'not_detected' 'detected']
# Rhinovirus/Enterovirus----------------------------, [nan 'detected' 'not_detected']
# Coronavirus HKU1----------------------------------, [nan 'not_detected' 'detected']
# Parainfluenza 3-----------------------------------, [nan 'not_detected' 'detected']
# Chlamydophila pneumoniae--------------------------, [nan 'not_detected' 'detected']
# Adenovirus----------------------------------------, [nan 'not_detected' 'detected']
# ...

# %%
for col in covid.select_dtypes('object'):
  plt.figure()
  covid[col].value_counts().plot.pie()

# %% [markdown]
# **RELATIONS ENTRE VARIABLES ET TARGET**

# %% [markdown]
# **Création de sous-ensembles positifs et négatifs**

# %%
#Création du sous ensembles positifs
covid[covid['SARS-Cov-2 exam result'] == 'positive']
# Out:
#       Patient age quantile SARS-Cov-2 exam result  \
# 67                       7               positive
# 284                     16               positive
# 513                     10               positive
# 568                      2               positive
# 676                     15               positive
# ...                    ...                    ...
# 5632                    16               positive
# 5633                     4               positive
# 5634                    15               positive
# 5639                     3               positive
# 5643                    19               positive
#
#       Patient addmited to regular ward (1=yes, 0=no)  \
# 67                                                 0
# 284                                                1
# 513                                                0
# 568                                                0
# 676                                                0
# ...

# %%
# Création d'une data frame positive
positive_df = covid[covid['SARS-Cov-2 exam result'] == 'positive']

# %%
# Création d'une data frame negative
negative_df = covid[covid['SARS-Cov-2 exam result'] == 'negative']

# %% [markdown]
# **Création de sous-ensembles blood et viral**

# %%
missing_rate = covid.isna().sum()/covid.shape[0]

# %%
blood_columns = covid.columns[(missing_rate < 0.9) & (missing_rate > 0.88)]

# %%
viral_columns = covid.columns[(missing_rate < 0.88) & (missing_rate > 0.75)]

# %% [markdown]
# **TARGET ET BLOOD**

# %%
for col in blood_columns:
  plt.figure()
  sns.distplot(positive_df[col], label='positive')
  sns.distplot(negative_df[col], label='negative')
  plt.legend()
# Out:
# <ipython-input-324-dc64eef28bf2>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(positive_df[col], label='positive')
# <ipython-input-324-dc64eef28bf2>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(negative_df[col], label='negative')
# ...

# %% [markdown]
# **Relation entre TARGET et AGE**

# %%
sns.countplot(x = 'Patient age quantile', hue='SARS-Cov-2 exam result', data=covid)
# Out:
# <Axes: xlabel='Patient age quantile', ylabel='count'>
